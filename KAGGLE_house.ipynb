# %%
import pandas as pd
import numpy as np

# %%
train=pd.read_csv('train_house.csv')
test=pd.read_csv('test_house.csv')

# %%
train.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
test.head()
# Out:
#      Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0  1461          20       RH         80.0    11622   Pave   NaN      Reg
# 1  1462          20       RL         81.0    14267   Pave   NaN      IR1
# 2  1463          60       RL         74.0    13830   Pave   NaN      IR1
# 3  1464          60       RL         78.0     9978   Pave   NaN      IR1
# 4  1465         120       RL         43.0     5005   Pave   NaN      IR1
#
#   LandContour Utilities  ... ScreenPorch PoolArea PoolQC  Fence MiscFeature  \
# 0         Lvl    AllPub  ...         120        0    NaN  MnPrv         NaN
# 1         Lvl    AllPub  ...           0        0    NaN    NaN        Gar2
# 2         Lvl    AllPub  ...           0        0    NaN  MnPrv         NaN
# 3         Lvl    AllPub  ...           0        0    NaN    NaN         NaN
# 4         HLS    AllPub  ...         144        0    NaN    NaN         NaN
#
#   MiscVal MoSold  YrSold  SaleType  SaleCondition
# ...

# %%
train.drop(['MSSubClass', 'LotFrontage',  'Alley', 'LotShape', 'LandContour', 'LotConfig',
       'LandSlope', 'Condition1', 'Condition2', 'BldgType',
       'HouseStyle', 'OverallQual', 'YearRemodAdd',
       'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType',
       'MasVnrArea', 'ExterQual', 'Foundation', 'BsmtQual',
     'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1',
       'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating',
       'HeatingQC', 'Electrical',
       'LowQualFinSF', 'KitchenQual', 'Functional', 'FireplaceQu', 'GarageType',
       'GarageYrBlt', 'GarageFinish', 'GarageCars', 'GarageQual',
       'GarageCond', 'PavedDrive', 'WoodDeckSF', 'OpenPorchSF',
       'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolQC',
       'MoSold','YrSold','SaleType'],axis='columns',inplace=True)

# %%
test.drop(['MSSubClass', 'LotFrontage',  'Alley', 'LotShape', 'LandContour', 'LotConfig',
       'LandSlope', 'Condition1', 'Condition2', 'BldgType',
       'HouseStyle', 'OverallQual', 'YearRemodAdd',
       'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType',
       'MasVnrArea', 'ExterQual', 'Foundation', 'BsmtQual',
     'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1',
       'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating',
       'HeatingQC', 'Electrical',
       'LowQualFinSF', 'KitchenQual', 'Functional', 'FireplaceQu', 'GarageType',
       'GarageYrBlt', 'GarageFinish', 'GarageCars', 'GarageQual',
       'GarageCond', 'PavedDrive', 'WoodDeckSF', 'OpenPorchSF',
       'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolQC',
       'MoSold','YrSold','SaleType'],axis='columns',inplace=True)

# %%
train.head()
# Out:
#    Id MSZoning  LotArea Street Utilities Neighborhood  OverallCond  YearBuilt  \
# 0   1       RL     8450   Pave    AllPub      CollgCr            5       2003
# 1   2       RL     9600   Pave    AllPub      Veenker            8       1976
# 2   3       RL    11250   Pave    AllPub      CollgCr            5       2001
# 3   4       RL     9550   Pave    AllPub      Crawfor            5       1915
# 4   5       RL    14260   Pave    AllPub      NoRidge            5       2000
#
#   ExterCond BsmtCond  ... KitchenAbvGr  TotRmsAbvGrd  Fireplaces  GarageArea  \
# 0        TA       TA  ...            1             8           0         548
# 1        TA       TA  ...            1             6           1         460
# 2        TA       TA  ...            1             6           1         608
# 3        TA       Gd  ...            1             7           1         642
# 4        TA       TA  ...            1             9           1         836
#
# ...

# %%
test.head()
# Out:
#      Id MSZoning  LotArea Street Utilities Neighborhood  OverallCond  \
# 0  1461       RH    11622   Pave    AllPub        NAmes            6
# 1  1462       RL    14267   Pave    AllPub        NAmes            6
# 2  1463       RL    13830   Pave    AllPub      Gilbert            5
# 3  1464       RL     9978   Pave    AllPub      Gilbert            6
# 4  1465       RL     5005   Pave    AllPub      StoneBr            5
#
#    YearBuilt ExterCond BsmtCond  ... BedroomAbvGr  KitchenAbvGr  TotRmsAbvGrd  \
# 0       1961        TA       TA  ...            2             1             5
# 1       1958        TA       TA  ...            3             1             6
# 2       1997        TA       TA  ...            3             1             6
# 3       1998        TA       TA  ...            3             1             7
# 4       1992        TA       TA  ...            2             1             5
#
#    Fireplaces  GarageArea  PoolArea  Fence  MiscFeature  MiscVal  \
# ...

# %%
train.isnull().sum()
# Out:
# Id                  0
# MSZoning            0
# LotArea             0
# Street              0
# Utilities           0
# Neighborhood        0
# OverallCond         0
# YearBuilt           0
# ExterCond           0
# BsmtCond           37
# CentralAir          0
# 1stFlrSF            0
# 2ndFlrSF            0
# GrLivArea           0
# BsmtFullBath        0
# BsmtHalfBath        0
# FullBath            0
# HalfBath            0
# BedroomAbvGr        0
# KitchenAbvGr        0
# TotRmsAbvGrd        0
# Fireplaces          0
# GarageArea          0
# PoolArea            0
# Fence            1179
# MiscFeature      1406
# MiscVal             0
# SaleCondition       0
# SalePrice           0
# dtype: int64

# %%
train.drop(['Fence','MiscFeature','MiscVal'],axis='columns',inplace=True)
test.drop(['Fence','MiscFeature','MiscVal'],axis='columns',inplace=True)

# %%
train.shape
# Out:
# (1460, 26)

# %%
train['total_house_area']=train['1stFlrSF']+train['2ndFlrSF']+train['GrLivArea']

# %%
train.head()
# Out:
#    Id MSZoning  LotArea Street Utilities Neighborhood  OverallCond  YearBuilt  \
# 0   1       RL     8450   Pave    AllPub      CollgCr            5       2003
# 1   2       RL     9600   Pave    AllPub      Veenker            8       1976
# 2   3       RL    11250   Pave    AllPub      CollgCr            5       2001
# 3   4       RL     9550   Pave    AllPub      Crawfor            5       1915
# 4   5       RL    14260   Pave    AllPub      NoRidge            5       2000
#
#   ExterCond BsmtCond  ... HalfBath  BedroomAbvGr  KitchenAbvGr  TotRmsAbvGrd  \
# 0        TA       TA  ...        1             3             1             8
# 1        TA       TA  ...        0             3             1             6
# 2        TA       TA  ...        1             3             1             6
# 3        TA       Gd  ...        0             3             1             7
# 4        TA       TA  ...        1             4             1             9
#
# ...

# %%
test['total_house_area']=train['1stFlrSF']+train['2ndFlrSF']+train['GrLivArea']

# %%
test.head()
# Out:
#      Id MSZoning  LotArea Street Utilities Neighborhood  OverallCond  \
# 0  1461       RH    11622   Pave    AllPub        NAmes            6
# 1  1462       RL    14267   Pave    AllPub        NAmes            6
# 2  1463       RL    13830   Pave    AllPub      Gilbert            5
# 3  1464       RL     9978   Pave    AllPub      Gilbert            6
# 4  1465       RL     5005   Pave    AllPub      StoneBr            5
#
#    YearBuilt ExterCond BsmtCond  ... FullBath  HalfBath  BedroomAbvGr  \
# 0       1961        TA       TA  ...        1         0             2
# 1       1958        TA       TA  ...        1         1             3
# 2       1997        TA       TA  ...        2         1             3
# 3       1998        TA       TA  ...        2         1             3
# 4       1992        TA       TA  ...        2         0             2
#
#    KitchenAbvGr  TotRmsAbvGrd  Fireplaces  GarageArea  PoolArea  \
# ...

# %%
train.drop(['1stFlrSF','2ndFlrSF','GrLivArea'],axis='columns',inplace=True)
test.drop(['1stFlrSF','2ndFlrSF','GrLivArea'],axis='columns',inplace=True)

# %%
train.head()
# Out:
#    Id MSZoning  LotArea Street Utilities Neighborhood  OverallCond  YearBuilt  \
# 0   1       RL     8450   Pave    AllPub      CollgCr            5       2003
# 1   2       RL     9600   Pave    AllPub      Veenker            8       1976
# 2   3       RL    11250   Pave    AllPub      CollgCr            5       2001
# 3   4       RL     9550   Pave    AllPub      Crawfor            5       1915
# 4   5       RL    14260   Pave    AllPub      NoRidge            5       2000
#
#   ExterCond BsmtCond  ... HalfBath  BedroomAbvGr  KitchenAbvGr  TotRmsAbvGrd  \
# 0        TA       TA  ...        1             3             1             8
# 1        TA       TA  ...        0             3             1             6
# 2        TA       TA  ...        1             3             1             6
# 3        TA       Gd  ...        0             3             1             7
# 4        TA       TA  ...        1             4             1             9
#
# ...

# %%
test.head()
# Out:
#      Id MSZoning  LotArea Street Utilities Neighborhood  OverallCond  \
# 0  1461       RH    11622   Pave    AllPub        NAmes            6
# 1  1462       RL    14267   Pave    AllPub        NAmes            6
# 2  1463       RL    13830   Pave    AllPub      Gilbert            5
# 3  1464       RL     9978   Pave    AllPub      Gilbert            6
# 4  1465       RL     5005   Pave    AllPub      StoneBr            5
#
#    YearBuilt ExterCond BsmtCond  ... FullBath  HalfBath  BedroomAbvGr  \
# 0       1961        TA       TA  ...        1         0             2
# 1       1958        TA       TA  ...        1         1             3
# 2       1997        TA       TA  ...        2         1             3
# 3       1998        TA       TA  ...        2         1             3
# 4       1992        TA       TA  ...        2         0             2
#
#    KitchenAbvGr  TotRmsAbvGrd  Fireplaces  GarageArea  PoolArea  \
# ...

# %%
train.drop('LotArea',axis='columns',inplace=True)
test.drop('LotArea',axis='columns',inplace=True)

# %%
train.shape
# Out:
# (1460, 23)

# %%
test.shape
# Out:
# (1459, 22)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.scatterplot(x='SalePrice',y='total_house_area',data=train)

# %%
train=train[train['total_house_area']<=8000]

# %%
train=train[train['SalePrice']<=500000]

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1449 entries, 0 to 1459
# Data columns (total 23 columns):
# Id                  1449 non-null int64
# MSZoning            1449 non-null object
# Street              1449 non-null object
# Utilities           1449 non-null object
# Neighborhood        1449 non-null object
# OverallCond         1449 non-null int64
# YearBuilt           1449 non-null int64
# ExterCond           1449 non-null object
# BsmtCond            1412 non-null object
# CentralAir          1449 non-null object
# BsmtFullBath        1449 non-null int64
# BsmtHalfBath        1449 non-null int64
# FullBath            1449 non-null int64
# HalfBath            1449 non-null int64
# BedroomAbvGr        1449 non-null int64
# KitchenAbvGr        1449 non-null int64
# TotRmsAbvGrd        1449 non-null int64
# Fireplaces          1449 non-null int64
# GarageArea          1449 non-null int64
# PoolArea            1449 non-null int64
# ...

# %%
train.CentralAir.value_counts(dropna=False)
# Out:
# Y    1354
# N      95
# Name: CentralAir, dtype: int64

# %%
def Air(x):
    if x=='Y':
        return 1
    elif x=='N':
        return 0

# %%
train['Air']=train['CentralAir'].apply(Air)

# %%
test['Air']=test['CentralAir'].apply(Air)

# %%
train.drop('CentralAir',axis='columns',inplace=True)
test.drop('CentralAir',axis='columns',inplace=True)

# %%
train.head()
# Out:
#    Id MSZoning Street Utilities Neighborhood  OverallCond  YearBuilt  \
# 0   1       RL   Pave    AllPub      CollgCr            5       2003
# 1   2       RL   Pave    AllPub      Veenker            8       1976
# 2   3       RL   Pave    AllPub      CollgCr            5       2001
# 3   4       RL   Pave    AllPub      Crawfor            5       1915
# 4   5       RL   Pave    AllPub      NoRidge            5       2000
#
#   ExterCond BsmtCond  BsmtFullBath  ...  BedroomAbvGr  KitchenAbvGr  \
# 0        TA       TA             1  ...             3             1
# 1        TA       TA             0  ...             3             1
# 2        TA       TA             1  ...             3             1
# 3        TA       Gd             1  ...             3             1
# 4        TA       TA             1  ...             4             1
#
#    TotRmsAbvGrd  Fireplaces  GarageArea  PoolArea  SaleCondition  SalePrice  \
# ...

# %%
test.head()
# Out:
#      Id MSZoning Street Utilities Neighborhood  OverallCond  YearBuilt  \
# 0  1461       RH   Pave    AllPub        NAmes            6       1961
# 1  1462       RL   Pave    AllPub        NAmes            6       1958
# 2  1463       RL   Pave    AllPub      Gilbert            5       1997
# 3  1464       RL   Pave    AllPub      Gilbert            6       1998
# 4  1465       RL   Pave    AllPub      StoneBr            5       1992
#
#   ExterCond BsmtCond  BsmtFullBath  ...  HalfBath  BedroomAbvGr  KitchenAbvGr  \
# 0        TA       TA           0.0  ...         0             2             1
# 1        TA       TA           0.0  ...         1             3             1
# 2        TA       TA           0.0  ...         1             3             1
# 3        TA       TA           0.0  ...         1             3             1
# 4        TA       TA           0.0  ...         0             2             1
#
#    TotRmsAbvGrd  Fireplaces  GarageArea  PoolArea  SaleCondition  \
# ...

# %%
train.drop(['PoolArea','GarageArea','MSZoning','Street'],axis='columns',inplace=True)
test.drop(['PoolArea','GarageArea','MSZoning','Street'],axis='columns',inplace=True)

# %%
train.head()
# Out:
#    Id Utilities Neighborhood  OverallCond  YearBuilt ExterCond BsmtCond  \
# 0   1    AllPub      CollgCr            5       2003        TA       TA
# 1   2    AllPub      Veenker            8       1976        TA       TA
# 2   3    AllPub      CollgCr            5       2001        TA       TA
# 3   4    AllPub      Crawfor            5       1915        TA       Gd
# 4   5    AllPub      NoRidge            5       2000        TA       TA
#
#    BsmtFullBath  BsmtHalfBath  FullBath  HalfBath  BedroomAbvGr  KitchenAbvGr  \
# 0             1             0         2         1             3             1
# 1             0             1         2         0             3             1
# 2             1             0         2         1             3             1
# 3             1             0         1         0             3             1
# 4             1             0         2         1             4             1
#
# ...

# %%
test.head()
# Out:
#      Id Utilities Neighborhood  OverallCond  YearBuilt ExterCond BsmtCond  \
# 0  1461    AllPub        NAmes            6       1961        TA       TA
# 1  1462    AllPub        NAmes            6       1958        TA       TA
# 2  1463    AllPub      Gilbert            5       1997        TA       TA
# 3  1464    AllPub      Gilbert            6       1998        TA       TA
# 4  1465    AllPub      StoneBr            5       1992        TA       TA
#
#    BsmtFullBath  BsmtHalfBath  FullBath  HalfBath  BedroomAbvGr  KitchenAbvGr  \
# 0           0.0           0.0         1         0             2             1
# 1           0.0           0.0         1         1             3             1
# 2           0.0           0.0         2         1             3             1
# 3           0.0           0.0         2         1             3             1
# 4           0.0           0.0         2         0             2             1
#
# ...

# %%
train.shape
# Out:
# (1449, 19)

# %%
test.shape
# Out:
# (1459, 18)

# %%
train.isnull().sum()
# Out:
# Id                   0
# Utilities            0
# Neighborhood         0
# OverallCond          0
# YearBuilt            0
# ExterCond            0
# BsmtCond            37
# BsmtFullBath         0
# BsmtHalfBath         0
# FullBath             0
# HalfBath             0
# BedroomAbvGr         0
# KitchenAbvGr         0
# TotRmsAbvGrd         0
# Fireplaces           0
# SaleCondition        0
# SalePrice            0
# total_house_area     0
# Air                  0
# dtype: int64

# %%
train.drop(['YearBuilt','BsmtCond','ExterCond','Utilities'],axis='columns',inplace=True)
test.drop(['YearBuilt','BsmtCond','ExterCond','Utilities'],axis='columns',inplace=True)

# %%
train.shape
# Out:
# (1449, 15)

# %%
test.shape
# Out:
# (1459, 14)

# %%
train['Total_full_bath']=train['BsmtFullBath']+train['FullBath']
train['total_half_bath']=train['BsmtHalfBath']+train['HalfBath']

# %%
test['Total_full_bath']=test['BsmtFullBath']+test['FullBath']
test['total_half_bath']=test['BsmtHalfBath']+test['HalfBath']

# %%
train.drop(['BsmtFullBath','FullBath','BsmtHalfBath','HalfBath'],axis='columns',inplace=True)

# %%
test.drop(['BsmtFullBath','FullBath','BsmtHalfBath','HalfBath'],axis='columns',inplace=True)

# %%
train.shape
# Out:
# (1449, 13)

# %%
test.shape
# Out:
# (1459, 12)

# %%
train.head()
# Out:
#    Id Neighborhood  OverallCond  BedroomAbvGr  KitchenAbvGr  TotRmsAbvGrd  \
# 0   1      CollgCr            5             3             1             8
# 1   2      Veenker            8             3             1             6
# 2   3      CollgCr            5             3             1             6
# 3   4      Crawfor            5             3             1             7
# 4   5      NoRidge            5             4             1             9
#
#    Fireplaces SaleCondition  SalePrice  total_house_area  Air  \
# 0           0        Normal     208500              3420    1
# 1           1        Normal     181500              2524    1
# 2           1        Normal     223500              3572    1
# 3           1       Abnorml     140000              3434    1
# 4           1        Normal     250000              4396    1
#
#    Total_full_bath  total_half_bath
# 0                3                1
# 1                2                1
# ...

# %%
train.drop('BedroomAbvGr',axis='columns',inplace=True)
test.drop('BedroomAbvGr',axis='columns',inplace=True)

# %%
train.head()
# Out:
#    Id Neighborhood  OverallCond  KitchenAbvGr  TotRmsAbvGrd  Fireplaces  \
# 0   1      CollgCr            5             1             8           0
# 1   2      Veenker            8             1             6           1
# 2   3      CollgCr            5             1             6           1
# 3   4      Crawfor            5             1             7           1
# 4   5      NoRidge            5             1             9           1
#
#   SaleCondition  SalePrice  total_house_area  Air  Total_full_bath  \
# 0        Normal     208500              3420    1                3
# 1        Normal     181500              2524    1                2
# 2        Normal     223500              3572    1                3
# 3       Abnorml     140000              3434    1                2
# 4        Normal     250000              4396    1                3
#
#    total_half_bath
# 0                1
# 1                1
# 2                1
# 3                0
# 4                1

# %%
test.head()
# Out:
#      Id Neighborhood  OverallCond  KitchenAbvGr  TotRmsAbvGrd  Fireplaces  \
# 0  1461        NAmes            6             1             5           0
# 1  1462        NAmes            6             1             6           0
# 2  1463      Gilbert            5             1             6           1
# 3  1464      Gilbert            6             1             7           1
# 4  1465      StoneBr            5             1             5           0
#
#   SaleCondition  total_house_area  Air  Total_full_bath  total_half_bath
# 0        Normal              3420    1              1.0              0.0
# 1        Normal              2524    1              1.0              1.0
# 2        Normal              3572    1              2.0              1.0
# 3        Normal              3434    1              2.0              1.0
# 4        Normal              4396    1              2.0              0.0

# %%
train.shape
# Out:
# (1449, 12)

# %%
test.shape
# Out:
# (1459, 11)

# %%
train.corr()
# Out:
#                         Id  OverallCond  KitchenAbvGr  TotRmsAbvGrd  \
# Id                1.000000     0.013535      0.003297      0.022287
# OverallCond       0.013535     1.000000     -0.087800     -0.050153
# KitchenAbvGr      0.003297    -0.087800      1.000000      0.267515
# TotRmsAbvGrd      0.022287    -0.050153      0.267515      1.000000
# Fireplaces       -0.024699    -0.019725     -0.123101      0.309227
# SalePrice        -0.032725    -0.072269     -0.142884      0.514948
# total_house_area -0.002085    -0.075207      0.114984      0.828310
# Air               0.009427     0.119990     -0.246481      0.030148
# Total_full_bath   0.000765    -0.181331      0.075270      0.355167
# total_half_bath  -0.006545    -0.002821     -0.077433      0.293161
#
#                   Fireplaces  SalePrice  total_house_area       Air  \
# Id                 -0.024699  -0.032725         -0.002085  0.009427
# OverallCond        -0.019725  -0.072269         -0.075207  0.119990
# ...

# %%
train.drop(['OverallCond','KitchenAbvGr'],axis='columns',inplace=True)
test.drop(['OverallCond','KitchenAbvGr'],axis='columns',inplace=True)

# %%
train.head()
# Out:
#    Id Neighborhood  TotRmsAbvGrd  Fireplaces SaleCondition  SalePrice  \
# 0   1      CollgCr             8           0        Normal     208500
# 1   2      Veenker             6           1        Normal     181500
# 2   3      CollgCr             6           1        Normal     223500
# 3   4      Crawfor             7           1       Abnorml     140000
# 4   5      NoRidge             9           1        Normal     250000
#
#    total_house_area  Air  Total_full_bath  total_half_bath
# 0              3420    1                3                1
# 1              2524    1                2                1
# 2              3572    1                3                1
# 3              3434    1                2                0
# 4              4396    1                3                1

# %%
test.head()
# Out:
#      Id Neighborhood  TotRmsAbvGrd  Fireplaces SaleCondition  \
# 0  1461        NAmes             5           0        Normal
# 1  1462        NAmes             6           0        Normal
# 2  1463      Gilbert             6           1        Normal
# 3  1464      Gilbert             7           1        Normal
# 4  1465      StoneBr             5           0        Normal
#
#    total_house_area  Air  Total_full_bath  total_half_bath
# 0              3420    1              1.0              0.0
# 1              2524    1              1.0              1.0
# 2              3572    1              2.0              1.0
# 3              3434    1              2.0              1.0
# 4              4396    1              2.0              0.0

# %%
train=pd.get_dummies(train,['Neighborhood','SaleCondition'],drop_first=True)
test=pd.get_dummies(test,['Neighborhood','SaleCondition'],drop_first=True)

# %%
train.shape
# Out:
# (1449, 37)

# %%
test.shape
# Out:
# (1459, 36)

# %%
train.head()
# Out:
#    Id  TotRmsAbvGrd  Fireplaces  SalePrice  total_house_area  Air  \
# 0   1             8           0     208500              3420    1
# 1   2             6           1     181500              2524    1
# 2   3             6           1     223500              3572    1
# 3   4             7           1     140000              3434    1
# 4   5             9           1     250000              4396    1
#
#    Total_full_bath  total_half_bath  Neighborhood_Blueste  \
# 0                3                1                     0
# 1                2                1                     0
# 2                3                1                     0
# 3                2                0                     0
# 4                3                1                     0
#
#    Neighborhood_BrDale  ...  Neighborhood_SawyerW  Neighborhood_Somerst  \
# 0                    0  ...                     0                     0
# ...

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split

# %%
X=train.drop('SalePrice',axis=1).values
y=train['SalePrice'].values

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state=42)

# %%
reg_all = LinearRegression()

# %%
reg_all.fit(X_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
y_pred = reg_all.predict(X_test)

# %%
reg_all.score(X_test,y_test)
# Out:
# 0.7814010503248431

# %%
x=reg_all.predict(test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-72-98a0eaca9e74> in <module>
# ----> 1 x=reg_all.predict(test)
#
# D:\New folder\lib\site-packages\sklearn\linear_model\base.py in predict(self, X)
#     219             Returns predicted values.
#     220         """
# --> 221         return self._decision_function(X)
#     222
#     223     _preprocess_data = staticmethod(_preprocess_data)
#
# D:\New folder\lib\site-packages\sklearn\linear_model\base.py in _decision_function(self, X)
#     202         check_is_fitted(self, "coef_")
#     203
# --> 204         X = check_array(X, accept_sparse=['csr', 'csc', 'coo'])
#     205         return safe_sparse_dot(X, self.coef_.T,
#     206                                dense_output=True) + self.intercept_
#
# ...

# %%
from sklearn.model_selection import cross_val_score

# %% [raw]
# cv_scores = cross_val_score(reg_all, X, y, cv=5)
#
# # Print the 5-fold cross-validation scores
# print(cv_scores)
#
# # Print the average 5-fold cross-validation score
# print("Average 5-Fold CV Score: {}".format(np.mean(cv_scores)))

# %%
cv_scores = cross_val_score(reg_all, X, y, cv=5)

# Print the 5-fold cross-validation scores
print(cv_scores)

# Print the average 5-fold cross-validation score
print("Average 5-Fold CV Score: {}".format(np.mean(cv_scores)))
# Out:
# [0.81924496 0.83645966 0.78477063 0.77181536 0.74319426]
# Average 5-Fold CV Score: 0.7910969748062507

# %%
test.isnull().sum()
# Out:
# Id                       0
# TotRmsAbvGrd             0
# Fireplaces               0
# total_house_area         0
# Air                      0
# Total_full_bath          2
# total_half_bath          2
# Neighborhood_Blueste     0
# Neighborhood_BrDale      0
# Neighborhood_BrkSide     0
# Neighborhood_ClearCr     0
# Neighborhood_CollgCr     0
# Neighborhood_Crawfor     0
# Neighborhood_Edwards     0
# Neighborhood_Gilbert     0
# Neighborhood_IDOTRR      0
# Neighborhood_MeadowV     0
# Neighborhood_Mitchel     0
# Neighborhood_NAmes       0
# Neighborhood_NPkVill     0
# Neighborhood_NWAmes      0
# Neighborhood_NoRidge     0
# Neighborhood_NridgHt     0
# Neighborhood_OldTown     0
# Neighborhood_SWISU       0
# Neighborhood_Sawyer      0
# Neighborhood_SawyerW     0
# Neighborhood_Somerst     0
# Neighborhood_StoneBr     0
# Neighborhood_Timber      0
# Neighborhood_Veenker     0
# SaleCondition_AdjLand    0
# SaleCondition_Alloca     0
# SaleCondition_Family     0
# ...

# %%
test.Total_full_bath.value_counts(dropna=False)
# Out:
# 2.0    716
# 1.0    386
# 3.0    325
# 4.0     26
# 6.0      4
# NaN      2
# Name: Total_full_bath, dtype: int64

# %%
test.Total_full_bath.fillna(2,inplace=True)

# %%
test.total_half_bath.value_counts(dropna=False)
# Out:
# 0.0    844
# 1.0    581
# 2.0     32
# NaN      2
# Name: total_half_bath, dtype: int64

# %%
test.total_half_bath.fillna(0,inplace=True)

# %%
cv_scores = cross_val_score(reg_all, X, y, cv=3)

# Print the 5-fold cross-validation scores
print(cv_scores)

# Print the average 5-fold cross-validation score
print("Average 5-Fold CV Score: {}".format(np.mean(cv_scores)))
# Out:
# [0.82316594 0.78730685 0.76050119]
# Average 5-Fold CV Score: 0.7903246583443911

# %%
x_pred=reg_all.predict(test)

# %%
temp=pd.DataFrame(pd.DataFrame({"Id":test.Id,"SalePrice":x}))
temp.to_csv('1234.csv',index=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-82-91bf0211bb46> in <module>
# ----> 1 temp=pd.DataFrame(pd.DataFrame({"Id":test.Id,"SalePrice":x}))
#       2 temp.to_csv('1234.csv',index=False)
#
# NameError: name 'x' is not defined

# %%
print("R^2: {}".format(reg_all.score(X_test, y_test)))
rmse = np.sqrt(mean_squared_error(y_test, y_pred))
print("Root Mean Squared Error: {}".format(rmse))
# Out:
# R^2: 0.7814010503248431
# Root Mean Squared Error: 33804.51527718996

# %%
from sklearn.linear_model import Lasso

# %%
names=train.drop('SalePrice',axis=1).columns

# %%
lasso=Lasso(alpha=0.1)

# %%
lasso_coef=lasso.fit(X,y).coef_

# %%
train.head()
# Out:
#    Id  TotRmsAbvGrd  Fireplaces  SalePrice  total_house_area  Air  \
# 0   1             8           0     208500              3420    1
# 1   2             6           1     181500              2524    1
# 2   3             6           1     223500              3572    1
# 3   4             7           1     140000              3434    1
# 4   5             9           1     250000              4396    1
#
#    Total_full_bath  total_half_bath  Neighborhood_Blueste  \
# 0                3                1                     0
# 1                2                1                     0
# 2                3                1                     0
# 3                2                0                     0
# 4                3                1                     0
#
#    Neighborhood_BrDale  ...  Neighborhood_SawyerW  Neighborhood_Somerst  \
# 0                    0  ...                     0                     0
# ...

# %%
from sklearn.ensemble import RandomForestRegressor

rfr = RandomForestRegressor(n_estimators =100, criterion = 'mse',random_state = 42,n_jobs = -1)
rfr.fit(X_train,y_train)
rfr_pred_train = rfr.predict(X_train)
rfr_pred_test = rfr.predict(X_test)


print('MSE train_data: ', round((mean_squared_error(y_train,rfr_pred_train)), 1))
print('MSE test_data: ', round(mean_squared_error(y_test,rfr_pred_test), 1))
print('R2 train_data: ',round(r2_score(y_train,rfr_pred_train), 2))
print('R2 test_data: ', round(r2_score(y_test,rfr_pred_test), 2))
# Out:
# MSE train_data:  162689555.0
# MSE test_data:  1283144223.8
# R2 train_data:  0.97
# R2 test_data:  0.75
